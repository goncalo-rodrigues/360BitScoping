# %%
from scapy.all import *

# %%
a = rdpcap('pcaps/small_torrent.pcap')

# %%
s = a.sessions()
for k, v in s.iteritems():
    for pkt in v:
        b = pkt.getlayer('IP')
        if b is not None:
            print b.payload.name
#         try:
#             print pkt.getfieldval('load')
#         except:
#             pass
# Out:
# UDP
# TCP
# TCP
# TCP
# UDP
# TCP
# TCP
# TCP
# TCP
# TCP
# UDP
# UDP
# UDP
# UDP
# UDP
# UDP
# UDP
# UDP
# UDP
# UDP
# UDP
# UDP
# UDP
# UDP
# UDP
# UDP
# UDP
# TCP
# TCP
# TCP
# TCP
# TCP
# TCP
# TCP
# TCP
# UDP
# UDP
# UDP
# UDP
# UDP
# TCP
# TCP
# TCP
# TCP
# TCP
# TCP
# UDP
# TCP
# UDP
# UDP
# UDP
# UDP
# UDP
# UDP
# UDP
# UDP
# UDP
# UDP
# UDP
# UDP
# UDP
# UDP
# UDP
# UDP
# UDP
# UDP
# UDP
# UDP
# UDP
# UDP
# UDP
# UDP
# UDP
# UDP
# UDP
# UDP
# UDP
# UDP
# UDP
# UDP
# UDP
# UDP
# UDP
# UDP
# UDP
# UDP
# ICMP
# UDP
# UDP
# TCP
# TCP
# TCP
# UDP
# UDP
# UDP
# UDP
# UDP
# TCP
# TCP
# TCP
# UDP
# UDP
# UDP
# UDP
# UDP
# UDP
# UDP
# TCP
# TCP
# TCP
# TCP
# TCP
# TCP
# UDP
# UDP
# UDP
# UDP
# UDP
# UDP
# UDP
# UDP
# UDP
# UDP
# UDP
# UDP
# UDP
# UDP
# UDP
# UDP
# UDP
# UDP
# UDP
# UDP
# UDP
# UDP
# UDP
# UDP
# UDP
# UDP
# UDP
# UDP
# UDP
# UDP
# UDP
# UDP
# UDP
# UDP
# UDP
# UDP
# UDP
# UDP
# UDP
# UDP
# UDP
# UDP
# UDP
# UDP
# UDP
# TCP
# UDP
# UDP
# TCP
# TCP
# TCP
# TCP
# TCP
# ...
